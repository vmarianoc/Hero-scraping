# %%
import pandas as pd
from scipy.spatial import distance

# %%
heros_superpowers = pd.read_csv('superpoderes.csv')

# %%
def hero_sokalmichener_distance(heros_superpowers, hero_name = '3-D Man', features = ['Agility', 'Accelerated Healing', 'Lantern Power Ring']):
    result = []
    # Get the hero to be compared;
    main_hero = heros_superpowers.loc[heros_superpowers['hero_names'] == hero_name][features]
    
    # Compare using only the given features;
    heros_indexed_by_features = heros_superpowers[features]
    # For each line in the dataset, with the columns indexed by features, calculate the score and create a new column called 'Score'
    for index, row in heros_indexed_by_features.iterrows():
        result.append(distance.sokalmichener(main_hero, row))
    
    heros_indexed_by_features.insert(0, "Score", result, True) 
    return heros_indexed_by_features

# %%
hero_sokalmichener_distance(heros_superpowers).
# Out:
#      Score  Agility  Accelerated Healing  Lantern Power Ring
# 0      0.0     True                False               False
# 1      0.8    False                 True               False
# 2      0.5     True                 True               False
# 3      0.8    False                False                True
# 4      0.8    False                 True               False
# 5      0.5    False                False               False
# 6      0.5    False                False               False
# 7      0.8    False                 True               False
# 8      0.5    False                False               False
# 9      0.5    False                False               False
# 10     0.5    False                False               False
# 11     0.5    False                False               False
# 12     0.0     True                False               False
# 13     0.5    False                False               False
# 14     0.5     True                 True               False
# 15     0.5    False                False               False
# 16     0.0     True                False               False
# 17     0.5    False                False               False
# 18     0.5     True                False                True
# 19     0.5    False                False               False
# 20     0.5    False                False               False
# 21     0.5     True                 True               False
# 22     0.0     True                False               False
# 23     0.5    False                False               False
# 24     0.5    False                False               False
# 25     0.5    False                False               False
# 26     0.0     True                False               False
# 27     0.5    False                False               False
# 28     0.0     True                False               False
# 29     0.8    False                 True               False
# ..     ...      ...                  ...                 ...
# 637    0.5    False                False               False
# 638    0.5    False                False               False
# 639    0.5    False                False               False
# 640    0.5    False                False               False
# 641    0.5     True                 True               False
# 642    0.0     True                False               False
# 643    0.5    False                False               False
# 644    0.5    False                False               False
# 645    0.0     True                False               False
# 646    0.5    False                False               False
# 647    0.0     True                False               False
# 648    0.0     True                False               False
# 649    0.5    False                False               False
# 650    0.5     True                 True               False
# 651    0.0     True                False               False
# 652    0.5    False                False               False
# 653    0.5    False                False               False
# 654    0.5    False                False               False
# 655    0.5     True                 True               False
# 656    0.0     True                False               False
# 657    0.5    False                False               False
# 658    0.8    False                 True               False
# 659    0.5     True                 True               False
# 660    0.5    False                False               False
# 661    0.5    False                False               False
# 662    0.5    False                False               False
# 663    0.5    False                False               False
# 664    0.0     True                False               False
# 665    0.5    False                False               False
# 666    0.5    False                False               False
#
# [667 rows x 4 columns]

# %%
heros_superpowers.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# 1              False   False  ...         False            False       False
# 2              False   False  ...         False            False       False
# 3              False   False  ...         False            False       False
# 4              False   False  ...         False            False       False
#
#    Symbiote Costume  Speed Force  Phoenix Force  Molecular Dissipation  \
# 0             False        False          False                  False
# 1             False        False          False                  False
# 2             False        False          False                  False
# 3             False        False          False                  False
# 4             False        False          False                  False
#
#    Vision - Cryo  Omnipresent  Omniscient
# 0          False        False       False
# 1          False        False       False
# 2          False        False       False
# 3          False        False       False
# 4          False        False       False
#
# [5 rows x 168 columns]
